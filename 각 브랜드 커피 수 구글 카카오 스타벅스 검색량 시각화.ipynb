# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
ax = plt.subplot()
coffee_type = [143,88,79]
plt.bar(range(len(coffee_type)),coffee_type)
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['STARBUCKS', 'TWOSOMEPLACE', 'COFFEEBEAN'],rotation = 30)
plt.xlabel('Brands')
plt.ylabel('Coffee type')
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('starbucks_google.csv')

# %%
print(df)
# Out:
#           date  value
# 0   2019/12/22     73
# 1   2019/12/29     97
# 2   2020/01/05     80
# 3   2020/01/12     69
# 4   2020/01/19     75
# 5   2020/01/26     50
# 6   2020/02/02     65
# 7   2020/02/09     63
# 8   2020/02/16     48
# 9   2020/02/23     60
# 10  2020/03/01     51
# 11  2020/03/08     52
# 12  2020/03/15     63
# 13  2020/03/22     66
# 14  2020/03/29     65
# 15  2020/04/05     62
# 16  2020/04/12     64
# 17  2020/04/19     74
# 18  2020/04/26     68
# 19  2020/05/03     67
# 20  2020/05/10     70
# 21  2020/05/17     94
# 22  2020/05/24    100
# 23  2020/05/31     86
# 24  2020/06/07     95
# 25  2020/06/14     91
# 26  2020/06/21     93
# 27  2020/06/28     81
# 28  2020/07/05     91
# 29  2020/07/12     77
# 30  2020/07/19     99
# 31  2020/07/26     75
# 32  2020/08/02     78
# 33  2020/08/09     87
# 34  2020/08/16     84
# 35  2020/08/23     55
# 36  2020/08/30     50
# 37  2020/09/06     53
# 38  2020/09/13     63
# 39  2020/09/20     45
# ...

# %%
df.head()
# Out:
#          date  value
# 0  2019/12/22     73
# 1  2019/12/29     97
# 2  2020/01/05     80
# 3  2020/01/12     69
# 4  2020/01/19     75

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.title('google_starbucks')
plt.xlabel('Date')
plt.ylabel('number of search')
plt.plot(df['date'],df['value'])
plt.rcParams['figure.figsize'] = [30,15]
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('datatrend.csv')

# %%
df.head()
# Out:
#          date  value
# 0  2019-12-06     28
# 1  2019-12-07     29
# 2  2019-12-08     27
# 3  2019-12-09     30
# 4  2019-12-10     30

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.title('kakao_starbucks')
plt.xlabel('Date')
plt.ylabel('number of search')
plt.plot(df['date'],df['value'])
plt.rcParams['figure.figsize'] = [50,25]
plt.xticks(rotation=90)
plt.show()
